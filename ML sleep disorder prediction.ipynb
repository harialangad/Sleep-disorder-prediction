# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv(r"C:\Users\Harikrishnan\OneDrive\Desktop\csv\Sleep_health_and_lifestyle_dataset.csv")
data
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
data.isnull().sum()
# Out:
# Person ID                    0
# Gender                       0
# Age                          0
# Occupation                   0
# Sleep Duration               0
# Quality of Sleep             0
# Physical Activity Level      0
# Stress Level                 0
# BMI Category                 0
# Blood Pressure               0
# Heart Rate                   0
# Daily Steps                  0
# Sleep Disorder             219
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 155 entries, 3 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                155 non-null    int64
#  1   Gender                   155 non-null    object
#  2   Age                      155 non-null    int64
#  3   Occupation               155 non-null    object
#  4   Sleep Duration           155 non-null    float64
#  5   Quality of Sleep         155 non-null    int64
#  6   Physical Activity Level  155 non-null    int64
#  7   Stress Level             155 non-null    int64
#  8   BMI Category             155 non-null    object
#  9   Blood Pressure           155 non-null    object
#  10  Heart Rate               155 non-null    int64
#  11  Daily Steps              155 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 17.0+ KB

# %%
data.describe
# Out:
# <bound method NDFrame.describe of      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# 5            6    Male   28     Software Engineer             5.9
# 6            7    Male   29               Teacher             6.3
# 16          17  Female   29                 Nurse             6.5
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level   BMI Category  \
# ...

# %%
data.shape
# Out:
# (155, 13)

# %%
data.dtypes
# Out:
# Person ID                    int64
# Gender                      object
# Age                          int64
# Occupation                  object
# Sleep Duration             float64
# Quality of Sleep             int64
# Physical Activity Level      int64
# Stress Level                 int64
# BMI Category                object
# Blood Pressure              object
# Heart Rate                   int64
# Daily Steps                  int64
# Sleep Disorder              object
# dtype: object

# %%
data.size
# Out:
# 2015

# %%
data.head(1)
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 3          4   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 3                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 3         140/90          85         3000    Sleep Apnea

# %%
ob1=LabelEncoder()
ob2=LabelEncoder()
ob3=LabelEncoder()
ob4=LabelEncoder()
ob5=LabelEncoder()

data['Gender']=ob1.fit_transform(data['Gender'])
data['Occupation']=ob2.fit_transform(data['Occupation'])
data['BMI Category']=ob3.fit_transform(data['BMI Category'])
data['Blood Pressure']=ob4.fit_transform(data['Blood Pressure'])
# data['Sleep Disorder']=ob2.fit_transform(data['Sleep Disorder'])

# %%
x=data.drop(['Sleep Disorder'],axis=1)
y=data['Sleep Disorder']

# %%
# LOGISTIC REGRESSION

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model1=LogisticRegression()
model1.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
pred_y=model1.predict(xtest)
pred_y
# Out:
# array(['Insomnia', 'Sleep Apnea', 'Insomnia', 'Insomnia', 'Insomnia',
#        'Insomnia', 'Sleep Apnea', 'Sleep Apnea', 'Sleep Apnea',
#        'Insomnia', 'Sleep Apnea', 'Sleep Apnea', 'Insomnia', 'Insomnia',
#        'Insomnia', 'Sleep Apnea', 'Insomnia', 'Sleep Apnea',
#        'Sleep Apnea', 'Sleep Apnea', 'Insomnia', 'Insomnia',
#        'Sleep Apnea', 'Insomnia', 'Insomnia', 'Sleep Apnea',
#        'Sleep Apnea', 'Insomnia', 'Sleep Apnea', 'Sleep Apnea',
#        'Sleep Apnea'], dtype=object)

# %%
print(model1.score(xtrain,ytrain))
print(model1.score(xtest,ytest))
# Out:
# 0.9032258064516129
# 0.7741935483870968

# %%
data.head(2)
# Out:
#    Person ID  Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 3          4       1   28           5             5.9                 4
# 4          5       1   28           5             5.9                 4
#
#    Physical Activity Level  Stress Level  BMI Category  Blood Pressure  \
# 3                       30             8             2              11
# 4                       30             8             2              11
#
#    Heart Rate  Daily Steps Sleep Disorder
# 3          85         3000    Sleep Apnea
# 4          85         3000    Sleep Apnea

# %%
model1.predict([[4,1,28,5,5.9,4,30,8,2,11,85,3000]])
# model1.predict([[25,0,50000,1,1,0,1]])
# Out:
# array(['Sleep Apnea'], dtype=object)

# %%
# DECISION TREE CLASSIFIER

# %%
model2=DecisionTreeClassifier()
model2.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
pred2=model2.predict(xtest)
pred2
# Out:
# array(['Insomnia', 'Sleep Apnea', 'Insomnia', 'Insomnia', 'Insomnia',
#        'Insomnia', 'Sleep Apnea', 'Sleep Apnea', 'Sleep Apnea',
#        'Insomnia', 'Insomnia', 'Sleep Apnea', 'Insomnia', 'Insomnia',
#        'Sleep Apnea', 'Insomnia', 'Insomnia', 'Sleep Apnea',
#        'Sleep Apnea', 'Sleep Apnea', 'Insomnia', 'Sleep Apnea',
#        'Insomnia', 'Sleep Apnea', 'Insomnia', 'Sleep Apnea',
#        'Sleep Apnea', 'Sleep Apnea', 'Sleep Apnea', 'Sleep Apnea',
#        'Sleep Apnea'], dtype=object)

# %%
print(model2.score(xtrain,ytrain))
print(model2.score(xtest,ytest))
# Out:
# 1.0
# 0.8064516129032258

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm = confusion_matrix(ytest, pred2)
print(cm)
# Out:
# [[11  3]
#  [ 3 14]]

# %%
model2.predict([[4,1,28,5,5.9,4,30,8,2,11,85,3000]])
# Out:
# array(['Sleep Apnea'], dtype=object)

# %%
# RANDOM FOREST CLASSICATION

# %%
model3=RandomForestClassifier(n_estimators=100)
model3.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
print(model3.score(xtrain,ytrain))
print(model3.score(xtest,ytest))
# Out:
# 1.0
# 0.8387096774193549

# %%
pred3=model3.predict(xtest)
pred3
# Out:
# array(['Insomnia', 'Sleep Apnea', 'Insomnia', 'Insomnia', 'Insomnia',
#        'Insomnia', 'Sleep Apnea', 'Sleep Apnea', 'Sleep Apnea',
#        'Insomnia', 'Insomnia', 'Sleep Apnea', 'Insomnia', 'Insomnia',
#        'Insomnia', 'Sleep Apnea', 'Insomnia', 'Sleep Apnea',
#        'Sleep Apnea', 'Sleep Apnea', 'Insomnia', 'Sleep Apnea',
#        'Insomnia', 'Sleep Apnea', 'Insomnia', 'Sleep Apnea',
#        'Sleep Apnea', 'Insomnia', 'Sleep Apnea', 'Sleep Apnea',
#        'Sleep Apnea'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm = confusion_matrix(ytest, pred3)
print(cm)
# Out:
# [[12  2]
#  [ 3 14]]

# %%
model3.predict([[4,1,28,5,5.9,4,30,8,2,11,85,3000]])
# Out:
# array(['Sleep Apnea'], dtype=object)

# %%
# KNN CLASSIFIER

# %%
scaler=StandardScaler()
xtrain=scaler.fit_transform(xtrain)

# %%
model4=KNeighborsClassifier(n_neighbors=9)
model4.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
print(model4.score(xtrain,ytrain))
print(model4.score(xtest,ytest))
# Out:
# 0.9112903225806451
# 0.5483870967741935

# %%
pred4=model4.predict(xtest)
pred4
# Out:
# array(['Sleep Apnea', 'Sleep Apnea', 'Sleep Apnea', 'Sleep Apnea',
#        'Sleep Apnea', 'Sleep Apnea', 'Sleep Apnea', 'Sleep Apnea',
#        'Sleep Apnea', 'Sleep Apnea', 'Sleep Apnea', 'Sleep Apnea',
#        'Sleep Apnea', 'Sleep Apnea', 'Sleep Apnea', 'Sleep Apnea',
#        'Sleep Apnea', 'Sleep Apnea', 'Sleep Apnea', 'Sleep Apnea',
#        'Sleep Apnea', 'Sleep Apnea', 'Sleep Apnea', 'Sleep Apnea',
#        'Sleep Apnea', 'Sleep Apnea', 'Sleep Apnea', 'Sleep Apnea',
#        'Sleep Apnea', 'Sleep Apnea', 'Sleep Apnea'], dtype=object)

# %%
model2.predict([[4,1,28,5,5.9,4,30,8,2,11,85,3000]])
# Out:
# array(['Sleep Apnea'], dtype=object)

# %%
# ADABOOST CLASSIFIER

# %%
model5=AdaBoostClassifier(n_estimators=50,learning_rate=0.3,random_state=42)
model5.fit(xtrain,ytrain)
# Out:
# AdaBoostClassifier(learning_rate=0.3, random_state=42)

# %%
print(model5.score(xtrain,ytrain))
print(model5.score(xtest,ytest))
# Out:
# 0.9516129032258065
# 0.5483870967741935

# %%
pred5=model5.predict(xtest)

# %%
model2.predict([[4,1,28,5,5.9,4,30,8,2,11,85,3000]])
# Out:
# array(['Sleep Apnea'], dtype=object)

# %%
# GRADIENT BOOST CLASSIFIER

# %%
model6=GradientBoostingClassifier(n_estimators=250,random_state=1)
model6.fit(xtrain,ytrain)
# Out:
# GradientBoostingClassifier(n_estimators=250, random_state=1)

# %%
print(model6.score(xtrain,ytrain))
print(model6.score(xtest,ytest))
# Out:
# 1.0
# 0.5483870967741935

# %%
pred6=model6.predict(xtest)

# %%
model2.predict([[4,1,28,5,5.9,4,30,8,2,11,85,3000]])
# Out:
# array(['Sleep Apnea'], dtype=object)

# %%
data.head(1)
# Out:
#    Person ID  Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 3          4       1   28           5             5.9                 4
#
#    Physical Activity Level  Stress Level  BMI Category  Blood Pressure  \
# 3                       30             8             2              11
#
#    Heart Rate  Daily Steps Sleep Disorder
# 3          85         3000    Sleep Apnea

# %%
Person_ID=input("enter the Person ID:")
Gender=input("enter the gender:")
Gender=ob1.transform([Gender])
Age=input("enter age:")
Occupation=input("enter Occupation:")
Occupation=ob2.transform([Occupation])
Sleep_Duration=input("enter the Sleep Duration:")
Quality_of_Sleep=input("enter Quality of Sleep:")
Physical_Activity_Level=input("enter Physical Activity Level:")
Stress_Level=input("enter Stress Level:")
BMI_Category=input("enter BMI Category:")
BMI_Category=ob3.transform([BMI_Category])
Blood_Pressure=input("enter Blood Pressure:")
Blood_Pressure=ob4.transform([Blood_Pressure])
Heart_Rate=input("enter Heart Rate:")
Daily_Steps=input("enter Daily Steps:")
print(model2.predict([[Person_ID,Gender[0],Age,Occupation[0],Sleep_Duration,Quality_of_Sleep,Physical_Activity_Level,Stress_Level,BMI_Category[0],Blood_Pressure[0],Heart_Rate,Daily_Steps]]))
# Out:
# enter the Person ID: 4
# enter the gender: Male
# enter age: 28
# enter Occupation: Sales Representative
# enter the Sleep Duration: 5.9
# enter Quality of Sleep: 4
# enter Physical Activity Level: 30
# enter Stress Level: 8
# enter BMI Category: Obese
# enter Blood Pressure: 140/90
# enter Heart Rate: 85
# enter Daily Steps: 3000
# ['Sleep Apnea']

# %%
# 4	Male	28	Sales Representative	5.9	4	30	8	Obese	140/90	85	3000
